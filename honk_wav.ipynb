# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import math
import scipy.integrate as si
import numpy as np
import time
from datetime import datetime
from matplotlib import collections as matcoll
from scipy.io import wavfile
from pylab import rcParams

# %%
sns.set()
rcParams['figure.figsize'] = 10, 5

# %% [markdown]
# ## self honk while phone with scooty is stationary

# %%
# self honk while phone and scooty is stationary

# Load the data and calculate the time of each sample
samplerate, event1 = wavfile.read("C:\\Users\\krsai\\OneDrive\\Desktop\\sound_recorder\\Self(stationary)\\stationary_self.wav")
times = np.arange(len(event1))/float(samplerate)

plt.plot(event1)

# %% [markdown]
# ## self honk while phone with scooty is in motion

# %%
# self honk while phone and scooty is in motion sample 1

samplerate, event2_1 = wavfile.read("C:\\Users\\krsai\\OneDrive\\Desktop\\sound_recorder\\Self(motion)\\self_motion_1.wav")
times = np.arange(len(event1))/float(samplerate)

plt.plot(event2_1)

# %%
# self honk while phone and scooty is in motion sample 2

samplerate, event2_2 = wavfile.read("C:\\Users\\krsai\\OneDrive\\Desktop\\sound_recorder\\Self(motion)\\self_motion_2.wav")
times = np.arange(len(event1))/float(samplerate)

plt.plot(event2_2)

# %% [markdown]
# ## another scooty honk while phone is stationary

# %%
# another scooty honk while phone is stationary at 5m apart

samplerate, event3_5 = wavfile.read("C:\\Users\\krsai\\OneDrive\\Desktop\\sound_recorder\\Phone_rest(sccoty_motion)\\another_motion_5.wav")
times = np.arange(len(event1))/float(samplerate)

plt.plot(event3_5)

# %%
# another scooty honk while phone is stationary at 4m apart

samplerate, event3_4 = wavfile.read("C:\\Users\\krsai\\OneDrive\\Desktop\\sound_recorder\\Phone_rest(sccoty_motion)\\another_motion_4.wav")
times = np.arange(len(event1))/float(samplerate)

plt.plot(event3_4)

# %%
# another scooty honk while phone is stationary at 3m apart

samplerate, event3_3 = wavfile.read("C:\\Users\\krsai\\OneDrive\\Desktop\\sound_recorder\\Phone_rest(sccoty_motion)\\another_motion_3.wav")
times = np.arange(len(event1))/float(samplerate)

plt.plot(event3_3)

# %%
# another scooty honk while phone is stationary at 5m apart

samplerate, event3_2 = wavfile.read("C:\\Users\\krsai\\OneDrive\\Desktop\\sound_recorder\\Phone_rest(sccoty_motion)\\another_motion_2.wav")
times = np.arange(len(event1))/float(samplerate)

plt.plot(event3_2)

# %%
# another scooty honk while phone is stationary at 1m apart

samplerate, event3_1 = wavfile.read("C:\\Users\\krsai\\OneDrive\\Desktop\\sound_recorder\\Phone_rest(sccoty_motion)\\another_motion_1.wav")
times = np.arange(len(event1))/float(samplerate)

plt.plot(event3_1)
